# %%
# Out:
# Collecting python-poppler
#   Downloading python-poppler-0.3.0.tar.gz (823 kB)
# Building wheels for collected packages: python-poppler
#   Building wheel for python-poppler (setup.py): started
#   Building wheel for python-poppler (setup.py): finished with status 'error'
#   Running setup.py clean for python-poppler
# Failed to build python-poppler
# Installing collected packages: python-poppler
#     Running setup.py install for python-poppler: started
#     Running setup.py install for python-poppler: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\tmcgl\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\tmcgl\\AppData\\Local\\Temp\\pip-install-6xkt8sm0\\python-poppler_7add5080256f4a2687f862d7de0aa905\\setup.py'"'"'; __file__='"'"'C:\\Users\\tmcgl\\AppData\\Local\\Temp\\pip-install-6xkt8sm0\\python-poppler_7add5080256f4a2687f862d7de0aa905\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\tmcgl\AppData\Local\Temp\pip-wheel-bxbpqqcb'
#        cwd: C:\Users\tmcgl\AppData\Local\Temp\pip-install-6xkt8sm0\python-poppler_7add5080256f4a2687f862d7de0aa905\
#   Complete output (71 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.8
#   creating build\lib.win-amd64-3.8\poppler
#   copying src\poppler\destination.py -> build\lib.win-amd64-3.8\poppler
#   copying src\poppler\document.py -> build\lib.win-amd64-3.8\poppler
#   copying src\poppler\embeddedfile.py -> build\lib.win-amd64-3.8\poppler
#   copying src\poppler\font.py -> build\lib.win-amd64-3.8\poppler
#   copying src\poppler\image.py -> build\lib.win-amd64-3.8\poppler
#   copying src\poppler\page.py -> build\lib.win-amd64-3.8\poppler
#   copying src\poppler\pagerenderer.py -> build\lib.win-amd64-3.8\poppler
#   copying src\poppler\pagetransition.py -> build\lib.win-amd64-3.8\poppler
#   copying src\poppler\rectangle.py -> build\lib.win-amd64-3.8\poppler
#   copying src\poppler\toc.py -> build\lib.win-amd64-3.8\poppler
#   copying src\poppler\utilities.py -> build\lib.win-amd64-3.8\poppler
#   copying src\poppler\_version.py -> build\lib.win-amd64-3.8\poppler
#   copying src\poppler\__init__.py -> build\lib.win-amd64-3.8\poppler
#   creating build\lib.win-amd64-3.8\poppler\cpp
#   copying src\poppler\cpp\__init__.py -> build\lib.win-amd64-3.8\poppler\cpp
#   running egg_info
#   writing src\python_poppler.egg-info\PKG-INFO
#   writing dependency_links to src\python_poppler.egg-info\dependency_links.txt
#   writing top-level names to src\python_poppler.egg-info\top_level.txt
#   reading manifest file 'src\python_poppler.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   writing manifest file 'src\python_poppler.egg-info\SOURCES.txt'
#   running build_ext
#   Traceback (most recent call last):
#     File "C:\Users\tmcgl\AppData\Local\Temp\pip-install-6xkt8sm0\python-poppler_7add5080256f4a2687f862d7de0aa905\setup.py", line 24, in run
#       out = subprocess.check_output(["cmake", "--version"])
#     File "C:\Users\tmcgl\anaconda3\lib\subprocess.py", line 415, in check_output
#       return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     File "C:\Users\tmcgl\anaconda3\lib\subprocess.py", line 493, in run
#       with Popen(*popenargs, **kwargs) as process:
#     File "C:\Users\tmcgl\anaconda3\lib\subprocess.py", line 858, in __init__
#       self._execute_child(args, executable, preexec_fn, close_fds,
#     File "C:\Users\tmcgl\anaconda3\lib\subprocess.py", line 1311, in _execute_child
#       hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#   FileNotFoundError: [WinError 2] The system cannot find the file specified
#
#   During handling of the above exception, another exception occurred:
#
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\tmcgl\AppData\Local\Temp\pip-install-6xkt8sm0\python-poppler_7add5080256f4a2687f862d7de0aa905\setup.py", line 76, in <module>
#       setup(
#     File "C:\Users\tmcgl\anaconda3\lib\site-packages\setuptools\__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "C:\Users\tmcgl\anaconda3\lib\distutils\core.py", line 148, in setup
#       dist.run_commands()
#     File "C:\Users\tmcgl\anaconda3\lib\distutils\dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\tmcgl\anaconda3\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\tmcgl\anaconda3\lib\site-packages\wheel\bdist_wheel.py", line 299, in run
#       self.run_command('build')
#     File "C:\Users\tmcgl\anaconda3\lib\distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\tmcgl\anaconda3\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\tmcgl\anaconda3\lib\distutils\command\build.py", line 135, in run
#       self.run_command(cmd_name)
#     File "C:\Users\tmcgl\anaconda3\lib\distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\tmcgl\anaconda3\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\tmcgl\AppData\Local\Temp\pip-install-6xkt8sm0\python-poppler_7add5080256f4a2687f862d7de0aa905\setup.py", line 26, in run
#       raise RuntimeError(
#   RuntimeError: CMake must be installed to build the following extensions: poppler.cpp.modules
#   ----------------------------------------
#   ERROR: Failed building wheel for python-poppler
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\tmcgl\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\tmcgl\\AppData\\Local\\Temp\\pip-install-6xkt8sm0\\python-poppler_7add5080256f4a2687f862d7de0aa905\\setup.py'"'"'; __file__='"'"'C:\\Users\\tmcgl\\AppData\\Local\\Temp\\pip-install-6xkt8sm0\\python-poppler_7add5080256f4a2687f862d7de0aa905\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\tmcgl\AppData\Local\Temp\pip-record-bgpuut__\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\tmcgl\anaconda3\Include\python-poppler'
#          cwd: C:\Users\tmcgl\AppData\Local\Temp\pip-install-6xkt8sm0\python-poppler_7add5080256f4a2687f862d7de0aa905\
#     Complete output (73 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.8
#     creating build\lib.win-amd64-3.8\poppler
#     copying src\poppler\destination.py -> build\lib.win-amd64-3.8\poppler
#     copying src\poppler\document.py -> build\lib.win-amd64-3.8\poppler
#     copying src\poppler\embeddedfile.py -> build\lib.win-amd64-3.8\poppler
#     copying src\poppler\font.py -> build\lib.win-amd64-3.8\poppler
#     copying src\poppler\image.py -> build\lib.win-amd64-3.8\poppler
#     copying src\poppler\page.py -> build\lib.win-amd64-3.8\poppler
#     copying src\poppler\pagerenderer.py -> build\lib.win-amd64-3.8\poppler
#     copying src\poppler\pagetransition.py -> build\lib.win-amd64-3.8\poppler
#     copying src\poppler\rectangle.py -> build\lib.win-amd64-3.8\poppler
#     copying src\poppler\toc.py -> build\lib.win-amd64-3.8\poppler
#     copying src\poppler\utilities.py -> build\lib.win-amd64-3.8\poppler
#     copying src\poppler\_version.py -> build\lib.win-amd64-3.8\poppler
#     copying src\poppler\__init__.py -> build\lib.win-amd64-3.8\poppler
#     creating build\lib.win-amd64-3.8\poppler\cpp
#     copying src\poppler\cpp\__init__.py -> build\lib.win-amd64-3.8\poppler\cpp
#     running egg_info
#     writing src\python_poppler.egg-info\PKG-INFO
#     writing dependency_links to src\python_poppler.egg-info\dependency_links.txt
#     writing top-level names to src\python_poppler.egg-info\top_level.txt
#     reading manifest file 'src\python_poppler.egg-info\SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     writing manifest file 'src\python_poppler.egg-info\SOURCES.txt'
#     running build_ext
#     Traceback (most recent call last):
#       File "C:\Users\tmcgl\AppData\Local\Temp\pip-install-6xkt8sm0\python-poppler_7add5080256f4a2687f862d7de0aa905\setup.py", line 24, in run
#         out = subprocess.check_output(["cmake", "--version"])
#       File "C:\Users\tmcgl\anaconda3\lib\subprocess.py", line 415, in check_output
#         return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#       File "C:\Users\tmcgl\anaconda3\lib\subprocess.py", line 493, in run
#         with Popen(*popenargs, **kwargs) as process:
#       File "C:\Users\tmcgl\anaconda3\lib\subprocess.py", line 858, in __init__
#         self._execute_child(args, executable, preexec_fn, close_fds,
#       File "C:\Users\tmcgl\anaconda3\lib\subprocess.py", line 1311, in _execute_child
#         hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#     FileNotFoundError: [WinError 2] The system cannot find the file specified
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\tmcgl\AppData\Local\Temp\pip-install-6xkt8sm0\python-poppler_7add5080256f4a2687f862d7de0aa905\setup.py", line 76, in <module>
#         setup(
#       File "C:\Users\tmcgl\anaconda3\lib\site-packages\setuptools\__init__.py", line 153, in setup
#         return distutils.core.setup(**attrs)
#       File "C:\Users\tmcgl\anaconda3\lib\distutils\core.py", line 148, in setup
#         dist.run_commands()
#       File "C:\Users\tmcgl\anaconda3\lib\distutils\dist.py", line 966, in run_commands
#         self.run_command(cmd)
#       File "C:\Users\tmcgl\anaconda3\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\tmcgl\anaconda3\lib\site-packages\setuptools\command\install.py", line 61, in run
#         return orig.install.run(self)
#       File "C:\Users\tmcgl\anaconda3\lib\distutils\command\install.py", line 545, in run
#         self.run_command('build')
#       File "C:\Users\tmcgl\anaconda3\lib\distutils\cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "C:\Users\tmcgl\anaconda3\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\tmcgl\anaconda3\lib\distutils\command\build.py", line 135, in run
#         self.run_command(cmd_name)
#       File "C:\Users\tmcgl\anaconda3\lib\distutils\cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "C:\Users\tmcgl\anaconda3\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\tmcgl\AppData\Local\Temp\pip-install-6xkt8sm0\python-poppler_7add5080256f4a2687f862d7de0aa905\setup.py", line 26, in run
#         raise RuntimeError(
#     RuntimeError: CMake must be installed to build the following extensions: poppler.cpp.modules
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\tmcgl\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\tmcgl\\AppData\\Local\\Temp\\pip-install-6xkt8sm0\\python-poppler_7add5080256f4a2687f862d7de0aa905\\setup.py'"'"'; __file__='"'"'C:\\Users\\tmcgl\\AppData\\Local\\Temp\\pip-install-6xkt8sm0\\python-poppler_7add5080256f4a2687f862d7de0aa905\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\tmcgl\AppData\Local\Temp\pip-record-bgpuut__\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\tmcgl\anaconda3\Include\python-poppler' Check the logs for full command output.

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-349293227619> in <module>
# ----> 1 from pdf2image import convert_from_path
#       2 import easyocr
#       3 import numpy as np
#       4 import PIL
#       5 from PIL import ImageDraw
#
# ModuleNotFoundError: No module named 'pdf2image'

# %%
import pdf2image
try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract


def pdf_to_img(pdf_file):
    return pdf2image.convert_from_path(pdf_file)


def ocr_core(file):
    text = pytesseract.image_to_string(file)
    return text


def print_pages(pdf_file):
    images = pdf_to_img(pdf_file)
    for pg, img in enumerate(images):
        print(ocr_core(img))


print_pages('form_1120_2021.pdf')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pdf2image\pdf2image.py in pdfinfo_from_path(pdf_path, userpw, poppler_path, rawdates, timeout)
#     457             env["LD_LIBRARY_PATH"] = poppler_path + ":" + env.get("LD_LIBRARY_PATH", "")
# --> 458         proc = Popen(command, env=env, stdout=PIPE, stderr=PIPE)
#     459
#
# ~\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     857
# --> 858             self._execute_child(args, executable, preexec_fn, close_fds,
#     859                                 pass_fds, cwd, env,
#
# ~\anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1310             try:
# -> 1311                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1312                                          # no special security
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# PDFInfoNotInstalledError                  Traceback (most recent call last)
# <ipython-input-4-8bfea8681ccb> in <module>
#      22
#      23
# ---> 24 print_pages('form_1120_2021.pdf')
#
# <ipython-input-4-8bfea8681ccb> in print_pages(pdf_file)
#      17
#      18 def print_pages(pdf_file):
# ---> 19     images = pdf_to_img(pdf_file)
#      20     for pg, img in enumerate(images):
#      21         print(ocr_core(img))
#
# <ipython-input-4-8bfea8681ccb> in pdf_to_img(pdf_file)
#       8
#       9 def pdf_to_img(pdf_file):
# ---> 10     return pdf2image.convert_from_path(pdf_file)
#      11
#      12
#
# ~\anaconda3\lib\site-packages\pdf2image\pdf2image.py in convert_from_path(pdf_path, dpi, output_folder, first_page, last_page, fmt, jpegopt, thread_count, userpw, use_cropbox, strict, transparent, single_file, output_file, poppler_path, grayscale, size, paths_only, use_pdftocairo, timeout, hide_annotations)
#      96         poppler_path = poppler_path.as_posix()
#      97
# ---> 98     page_count = pdfinfo_from_path(pdf_path, userpw, poppler_path=poppler_path)["Pages"]
#      99
#     100     # We start by getting the output format, the buffer processing function and if we need pdftocairo
#
# ~\anaconda3\lib\site-packages\pdf2image\pdf2image.py in pdfinfo_from_path(pdf_path, userpw, poppler_path, rawdates, timeout)
#     482
#     483     except OSError:
# --> 484         raise PDFInfoNotInstalledError(
#     485             "Unable to get page count. Is poppler installed and in PATH?"
#     486         )
#
# PDFInfoNotInstalledError: Unable to get page count. Is poppler installed and in PATH?

# %%
# Import libraries
from PIL import Image
import pytesseract
import sys
from pdf2image import convert_from_path
import os

# Path of the pdf
PDF_file = "d.pdf"

'''
Part #1 : Converting PDF to images
'''

# Store all the pages of the PDF in a variable
pages = convert_from_path(PDF_file, 500)

# Counter to store images of each page of PDF to image
image_counter = 1

# Iterate through all the pages stored above
for page in pages:

# Declaring filename for each page of PDF as JPG
# For each page, filename will be:
# PDF page 1 -> page_1.jpg
# PDF page 2 -> page_2.jpg
# PDF page 3 -> page_3.jpg
# ....
# PDF page n -> page_n.jpg
    filename = "page_"+str(image_counter)+".jpg"

    # Save the image of the page in system
    page.save(filename, 'JPEG')

    # Increment the counter to update filename
    image_counter = image_counter + 1

'''
Part #2 - Recognizing text from the images using OCR
'''
#3
# Variable to get count of total number of pages
filelimit = image_counter-1

# Creating a text file to write the output
outfile = "out_text.txt"

# Open the file in append mode so that
# All contents of all images are added to the same file
f = open(outfile, "a")

# Iterate from 1 to total number of pages
for i in range(1, filelimit + 1):

# Set filename to recognize text from
# Again, these files will be:
# page_1.jpg
# page_2.jpg
# ....
# page_n.jpg
    filename = "page_"+str(i)+".jpg"

    # Recognize the text as string in image using pytesserct
    text = str(((pytesseract.image_to_string(Image.open(filename)))))


    text = text.replace('-\n', '')	

    f.write(text)

# Close the file after writing all the text.
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pdf2image\pdf2image.py in pdfinfo_from_path(pdf_path, userpw, poppler_path, rawdates, timeout)
#     457             env["LD_LIBRARY_PATH"] = poppler_path + ":" + env.get("LD_LIBRARY_PATH", "")
# --> 458         proc = Popen(command, env=env, stdout=PIPE, stderr=PIPE)
#     459
#
# ~\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     857
# --> 858             self._execute_child(args, executable, preexec_fn, close_fds,
#     859                                 pass_fds, cwd, env,
#
# ~\anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1310             try:
# -> 1311                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1312                                          # no special security
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# PDFInfoNotInstalledError                  Traceback (most recent call last)
# <ipython-input-11-642e8cb3bfdb> in <module>
#      14
#      15 # Store all the pages of the PDF in a variable
# ---> 16 pages = convert_from_path(PDF_file, 500)
#      17
#      18 # Counter to store images of each page of PDF to image
#
# ~\anaconda3\lib\site-packages\pdf2image\pdf2image.py in convert_from_path(pdf_path, dpi, output_folder, first_page, last_page, fmt, jpegopt, thread_count, userpw, use_cropbox, strict, transparent, single_file, output_file, poppler_path, grayscale, size, paths_only, use_pdftocairo, timeout, hide_annotations)
#      96         poppler_path = poppler_path.as_posix()
#      97
# ---> 98     page_count = pdfinfo_from_path(pdf_path, userpw, poppler_path=poppler_path)["Pages"]
#      99
#     100     # We start by getting the output format, the buffer processing function and if we need pdftocairo
#
# ~\anaconda3\lib\site-packages\pdf2image\pdf2image.py in pdfinfo_from_path(pdf_path, userpw, poppler_path, rawdates, timeout)
#     482
#     483     except OSError:
# --> 484         raise PDFInfoNotInstalledError(
#     485             "Unable to get page count. Is poppler installed and in PATH?"
#     486         )
#
# PDFInfoNotInstalledError: Unable to get page count. Is poppler installed and in PATH?
